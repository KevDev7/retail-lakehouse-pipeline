# %%
dbutils.fs.ls("/databricks-datasets/retail-org/")
# Out:
# [FileInfo(path='dbfs:/databricks-datasets/retail-org/README.md', name='README.md', size=1678, modificationTime=1602776043000),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/active_promotions/', name='active_promotions/', size=0, modificationTime=1765566139937),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/company_employees/', name='company_employees/', size=0, modificationTime=1765566139937),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/customers/', name='customers/', size=0, modificationTime=1765566139937),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/loyalty_segments/', name='loyalty_segments/', size=0, modificationTime=1765566139937),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/products/', name='products/', size=0, modificationTime=1765566139937),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/promotions/', name='promotions/', size=0, modificationTime=1765566139937),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/purchase_orders/', name='purchase_orders/', size=0, modificationTime=1765566139937),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/sales_orders/', name='sales_orders/', size=0, modificationTime=1765566139937),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/sales_stream/', name='sales_stream/', size=0, modificationTime=1765566139937),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/solutions/', name='solutions/', size=0, modificationTime=1765566139937),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/suppliers/', name='suppliers/', size=0, modificationTime=1765566139937)]

# %%
spark.read.text("/databricks-datasets/retail-org/README.md").show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                                                               |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Synthetic Retail Dataset                                                                                                                                            |
# |===============================                                                                                                                                     |
# |This dataset is a collection of files representing different dimensions and facts for a retail organization.                                                        |
# |                                                                                                                                                                    |
# |Provenance                                                                                                                                                          |
# |===============================                                                                                                                                     |
# |This dataset was generated by Databricks.                                                                                                                           |
# |                                                                                                                                                                    |
# |Data Set Information                                                                                                                                                |
# |====================                                                                                                                                                |
# |* Sales Orders: **sales_orders/sales_orders.json** records the customers' originating purchase order.                                                               |
# |* Purchase Orders: **purchase_orders/purchase_orders.xml** contains the raw materials that are being purchased.                                                     |
# |* Products: **products/products.csv** contains products that the company sells.                                                                                     |
# |* Goods Receipt: **goods_receipt/goods_receipt.parquet** contains the arrival time of purchased orders.                                                             |
# |* Customers: **customers/customers.csv** contains those customers who are located in the US and are buying the finished products.                                   |
# |* Suppliers: **suppliers/suppliers.csv** contains suppliers that provide raw materials in the US.                                                                   |
# |* Sales Stream: **sales_stream/sales_stream.json/** is a folder containing JSON files for streaming purposes.                                                       |
# |* Promotions: **promotions/promotions.csv** contains additional benefits on top of normal purchases.                                                                |
# |* Active Promotions: **active_promotions/active_promotions.parquet** shows how customers are progressing towards becoming eligible for promotions.                  |
# |* Loyalty Segment: **loyalty_segment/loyalty_segment.csv**  contains segmented customer data to appeal to all types of guests using targeted rewards and promotions.|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
