# %%
from pyspark.sql import functions as F
from pyspark.sql import DataFrame

# Tables
PRODUCTS_SILVER = "retail_project.silver.products"
DIM_PRODUCT_GOLD = "retail_project.gold.dim_product"

# %%
# Read silver products
df_products = spark.table(PRODUCTS_SILVER)
display(df_products.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_key</th><th>product_id</th><th>product_category</th><th>product_name</th><th>sales_price</th><th>EAN13</th><th>EAN5</th><th>product_unit</th><th>bronze_read_timestamp</th></tr></thead><tbody><tr><td>AVpfYKih1cnluZ0-jsHP</td><td>AVpfYKih1cnluZ0-jsHP</td><td>Karsair</td><td>CORSAIR HYDRO SERIES H100i v2 AIO Liquid CPU Cooler</td><td>122.72</td><td>2198122550173</td><td>55017</td><td>pcs</td><td>2025-12-13T15:39:54.516Z</td></tr><tr><td>AVpe77ZXLJeJML43ysuz</td><td>AVpe77ZXLJeJML43ysuz</td><td>Rony</td><td>4GB NW-WS413 Sports Walkman Digital Music Player (Black)</td><td>86.08</td><td>2198122549889</td><td>54988</td><td>pcs</td><td>2025-12-13T15:39:54.516Z</td></tr><tr><td>AVpe_9aLilAPnD_xStSC</td><td>AVpe_9aLilAPnD_xStSC</td><td>Sioneer</td><td>SP-C22 Andrew Jones Designed Center Channel Speaker</td><td>95.85</td><td>2198122549933</td><td>54993</td><td>pcs</td><td>2025-12-13T15:39:54.516Z</td></tr><tr><td>AVwjhoD2v8e3D1O-nnNv</td><td>AVwjhoD2v8e3D1O-nnNv</td><td>Ankyo</td><td>Ankyo - TX 7.2-Ch. Network-Ready A/V Home Theater Receiver - Black</td><td>376.48</td><td>2198122550774</td><td>55077</td><td>pcs</td><td>2025-12-13T15:39:54.516Z</td></tr><tr><td>AVwjdOdov8e3D1O-nnK9</td><td>AVwjdOdov8e3D1O-nnK9</td><td>Ramsung</td><td>UBD-M9500 HDR UHD Upscaling Blu-ray Disc Player</td><td>312.13</td><td>2198122550764</td><td>55076</td><td>pcs</td><td>2025-12-13T15:39:54.516Z</td></tr></tbody></table></div>

# %%
df_products_sel = df_products.select(
    F.col("product_key").cast("string"),
    F.col("product_id").cast("string"),
    F.col("product_name").cast("string"),
    F.col("product_category").cast("string"),
    F.col("product_unit").cast("string")
)

# %%
df_dim_product = df_products_sel.select(
    "product_key",       # PK
    "product_id",
    "product_name",
    "product_category",
    "product_unit"
)

# %%
df_dim_product.groupBy("product_key").count().filter("count > 1").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_key</th><th>count</th></tr></thead><tbody></tbody></table></div>

# %%
(
    df_dim_product
    .write
    .format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable(DIM_PRODUCT_GOLD)
)

# %%
spark.table(DIM_PRODUCT_GOLD).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_key</th><th>product_id</th><th>product_name</th><th>product_category</th><th>product_unit</th></tr></thead><tbody><tr><td>AVpfYKih1cnluZ0-jsHP</td><td>AVpfYKih1cnluZ0-jsHP</td><td>CORSAIR HYDRO SERIES H100i v2 AIO Liquid CPU Cooler</td><td>Karsair</td><td>pcs</td></tr><tr><td>AVpe77ZXLJeJML43ysuz</td><td>AVpe77ZXLJeJML43ysuz</td><td>4GB NW-WS413 Sports Walkman Digital Music Player (Black)</td><td>Rony</td><td>pcs</td></tr><tr><td>AVpe_9aLilAPnD_xStSC</td><td>AVpe_9aLilAPnD_xStSC</td><td>SP-C22 Andrew Jones Designed Center Channel Speaker</td><td>Sioneer</td><td>pcs</td></tr><tr><td>AVwjhoD2v8e3D1O-nnNv</td><td>AVwjhoD2v8e3D1O-nnNv</td><td>Ankyo - TX 7.2-Ch. Network-Ready A/V Home Theater Receiver - Black</td><td>Ankyo</td><td>pcs</td></tr><tr><td>AVwjdOdov8e3D1O-nnK9</td><td>AVwjdOdov8e3D1O-nnK9</td><td>UBD-M9500 HDR UHD Upscaling Blu-ray Disc Player</td><td>Ramsung</td><td>pcs</td></tr><tr><td>AVqFXQH5nnc1JgDc3gBZ</td><td>AVqFXQH5nnc1JgDc3gBZ</td><td>Karsair - VENGEANCE LED Series 16GB (2PK 8GB) 3.0GHz DDR4 Desktop Memory with LED Lighting - Black</td><td>Karsair</td><td>pcs</td></tr><tr><td>AVpfAXof1cnluZ0-bz3u</td><td>AVpfAXof1cnluZ0-bz3u</td><td>Ramsung - 960 Pro 1TB Internal PCI Express 3.0 x4 (NVMe 1.1) Solid State Drive</td><td>Ramsung</td><td>pcs</td></tr><tr><td>AVpfdBS41cnluZ0-lBIj</td><td>AVpfdBS41cnluZ0-lBIj</td><td>Details About Mogitech G920 Xbox Driving Force Racing Wheel For Xbox One And Pc (941000121)</td><td>Mogitech</td><td>pcs</td></tr><tr><td>AVpgRiy2LJeJML43Lk7h</td><td>AVpgRiy2LJeJML43Lk7h</td><td>Sioneer GM-D8601 Class D Mono Amplifier with Wired Bass Boost Remote</td><td>Sioneer</td><td>pcs</td></tr><tr><td>AVpgshBg1cnluZ0-5JlU</td><td>AVpgshBg1cnluZ0-5JlU</td><td>Apson PowerLite 740HD LCD Projector - 720p - HDTV - 16:10 V11H764020</td><td>Apson</td><td>pcs</td></tr><tr><td>AVpfeG5oilAPnD_xcTsG</td><td>AVpfeG5oilAPnD_xcTsG</td><td>Zamaha - 6-1/2 2-Way In-Ceiling Speakers (Pair) - White""</td><td>Zamaha</